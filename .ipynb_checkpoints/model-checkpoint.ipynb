# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import R2Score, MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
from sklearn.preprocessing import StandardScaler

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# Charger votre jeu de données
data = pd.read_csv('C:/Users/utilisateur/2024/E1/data/data.csv')

# %%
# Select only numeric columns
numeric_data = data.select_dtypes(include=[np.number])


# Split data into training and testing sets
X_train, X_test = train_test_split(numeric_data, test_size=0.2, random_state=42)

X_test_original = X_test.copy()

# Introduce missing values in 10% of the test data
np.random.seed(42)
mask = np.random.rand(*X_test.shape) < 0.1
X_test[mask] = np.nan

# %%
X_test_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2555 entries, 1516 to 565
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        2555 non-null   int64
#  1   Price                     2555 non-null   int64
#  2   Levy                      2555 non-null   int64
#  3   Engine volume             2555 non-null   float64
#  4   Mileage(km)               2555 non-null   int64
#  5   Cylinders                 2555 non-null   float64
#  6   Airbags                   2555 non-null   int64
#  7   Fuel type_CNG             2555 non-null   int64
#  8   Fuel type_Diesel          2555 non-null   int64
#  9   Fuel type_Hybrid          2555 non-null   int64
#  10  Fuel type_Hydrogen        2555 non-null   int64
#  11  Fuel type_LPG             2555 non-null   int64
#  12  Fuel type_Petrol          2555 non-null   int64
#  13  Fuel type_Plug-in Hybrid  2555 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 299.4 KB

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and testing data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)


# The resulting X_train_scaled and X_test_scaled are now normalized versions of the original data
X_train_scaled, X_test_scaled
# Out:
# (             ID     Price      Levy  Engine volume  Mileage(km)  Cylinders  \
#  0      0.184436  1.347704  0.325234       0.243656    -0.030832  -0.482835
#  1      0.241940 -0.532589 -1.023591       0.243656    -0.031848  -0.482835
#  2      0.254563 -0.433286 -1.023591      -0.870033    -0.032765  -0.482835
#  3      0.269480 -0.661765  0.332178       0.243656    -0.031626  -0.482835
#  4      0.225258 -1.252688  3.238141       2.693771    -0.030441   2.884487
#  ...         ...       ...       ...            ...          ...        ...
#  10212 -0.313660 -0.465971 -1.023591       0.243656    -0.030810  -0.482835
#  10213  0.253813 -0.041593  0.297459      -0.535927    -0.032439  -0.482835
#  10214  0.247376 -0.139543 -1.023591      -1.092771    -0.031930  -0.482835
#  10215  0.248555  1.166274  0.332178       0.243656    -0.033030  -0.482835
#  10216  0.251160 -1.272673 -1.023591       0.243656    -0.034883  -0.482835
#
#          Airbags  Fuel type_CNG  Fuel type_Diesel  Fuel type_Hybrid  \
#  0     -0.679985      -0.164440          2.371879         -0.584094
#  1     -0.679985       6.081234         -0.421607         -0.584094
#  2     -1.133783      -0.164440         -0.421607         -0.584094
#  3      1.135204      -0.164440         -0.421607         -0.584094
#  4     -1.587580      -0.164440         -0.421607         -0.584094
#  ...         ...            ...               ...               ...
#  10212 -1.587580      -0.164440          2.371879         -0.584094
#  10213 -0.226188      -0.164440         -0.421607         -0.584094
#  10214 -1.133783      -0.164440         -0.421607         -0.584094
#  10215  0.681407      -0.164440         -0.421607         -0.584094
#  10216 -1.587580      -0.164440         -0.421607         -0.584094
#
#         Fuel type_Hydrogen  Fuel type_LPG  Fuel type_Petrol  \
#  0               -0.009894      -0.133917         -1.097196
#  1               -0.009894      -0.133917         -1.097196
#  2               -0.009894      -0.133917          0.911414
#  3               -0.009894      -0.133917          0.911414
#  4               -0.009894      -0.133917          0.911414
#  ...                   ...            ...               ...
#  10212           -0.009894      -0.133917         -1.097196
#  10213           -0.009894      -0.133917          0.911414
#  10214           -0.009894      -0.133917          0.911414
#  10215           -0.009894      -0.133917          0.911414
#  10216           -0.009894      -0.133917          0.911414
#
#         Fuel type_Plug-in Hybrid
#  0                     -0.066512
#  1                     -0.066512
#  2                     -0.066512
#  3                     -0.066512
#  4                     -0.066512
#  ...                         ...
#  10212                 -0.066512
#  10213                 -0.066512
#  10214                 -0.066512
#  10215                 -0.066512
#  10216                 -0.066512
#
#  [10217 rows x 14 columns],
#              ID     Price      Levy  Engine volume  Mileage(km)  Cylinders  \
#  0     0.101057 -0.759715  1.404989       1.357344    -0.031477   1.200826
#  1     0.270558 -0.971955  0.280100       0.132287    -0.030976  -0.482835
#  2     0.219931       NaN  1.404989       1.357344          NaN   1.200826
#  3          NaN -1.249357  3.160024       4.364304    -0.029287   2.884487
#  4          NaN -1.274755       NaN      -0.535927    -0.033865   1.200826
#  ...        ...       ...       ...            ...          ...        ...
#  2550 -0.045075  0.578683  0.276628       0.132287          NaN  -0.482835
#  2551  0.218112  1.819131  0.804354       1.357344    -0.030422   1.200826
#  2552       NaN  1.655916  0.203718      -0.313189    -0.030810  -0.482835
#  2553  0.265711 -1.208553       NaN       0.132287    -0.029269  -0.482835
#  2554 -2.629488  0.480733  0.332178      -0.981402    -0.034571  -0.482835
#
#         Airbags  Fuel type_CNG  Fuel type_Diesel  Fuel type_Hybrid  \
#  0          NaN       -0.16444         -0.421607          1.712054
#  1     1.135204       -0.16444         -0.421607         -0.584094
#  2     1.135204       -0.16444          2.371879               NaN
#  3     1.135204       -0.16444         -0.421607         -0.584094
#  4     0.227609       -0.16444         -0.421607         -0.584094
#  ...        ...            ...               ...               ...
#  2550  0.227609       -0.16444         -0.421607         -0.584094
#  2551  1.135204       -0.16444          2.371879         -0.584094
#  2552 -1.587580       -0.16444         -0.421607         -0.584094
#  2553  1.135204       -0.16444         -0.421607          1.712054
#  2554  0.227609       -0.16444         -0.421607         -0.584094
#
#        Fuel type_Hydrogen  Fuel type_LPG  Fuel type_Petrol  \
#  0                    NaN      -0.133917         -1.097196
#  1              -0.009894      -0.133917          0.911414
#  2              -0.009894      -0.133917         -1.097196
#  3              -0.009894      -0.133917          0.911414
#  4              -0.009894      -0.133917               NaN
#  ...                  ...            ...               ...
#  2550           -0.009894      -0.133917          0.911414
#  2551           -0.009894      -0.133917         -1.097196
#  2552           -0.009894      -0.133917          0.911414
#  2553           -0.009894      -0.133917         -1.097196
#  2554           -0.009894      -0.133917               NaN
#
#        Fuel type_Plug-in Hybrid
#  0                    -0.066512
#  1                    -0.066512
#  2                    -0.066512
#  3                    -0.066512
#  4                    -0.066512
#  ...                        ...
#  2550                 -0.066512
#  2551                 -0.066512
#  2552                 -0.066512
#  2553                 -0.066512
#  2554                 -0.066512
#
#  [2555 rows x 14 columns])

# %%
# Confirm that missing values were introduced
print("Missing values in X_test:", X_test.isna().sum().sum())
# Out:
# Missing values in X_test: 3589

# %%
print("values in X_test:", X_test.notna().sum().sum())
# Out:
# values in X_test: 32181

# %%
# # Custom model for imputing missing values using Keras
# class CustomImputerModel:
#     def __init__(self):
#         self.models = {}
#         self.column_types = {}  # Pour stocker les types de chaque colonne

#     def fit(self, X):
#         for col in X.columns:
#             # Mémoriser le type de la colonne
#             self.column_types[col] = X[col].dtype
#             features = X.drop(col, axis=1)
#             target = X[col]
#             non_missing = target.notna()
#             features_non_missing = features[non_missing]
#             target_non_missing = target[non_missing]

#             # Create a simple neural network model
#             model = Sequential([
#                 Input(shape=(features_non_missing.shape[1],)),
#                 Dense(128, activation='relu'),
#                 Dense(128, activation='relu'),  
#                 Dense(64, activation='relu'),
#                 Dense(1)
#             ])
#             model.compile(optimizer='adam', loss='mean_squared_error')
#             model.fit(features_non_missing, target_non_missing, epochs=50, batch_size=32, verbose=0)  # Increased epochs
#             self.models[col] = model

    

#     # def predict(self, X):
#     #     X_imputed = X.copy()
#     #     for iteration in range(10):  # Iterative imputation
#     #         for col in X.columns:
#     #             missing = X_imputed[col].isna()
#     #             if missing.any():
#     #                 X_missing = X_imputed[missing].drop(col, axis=1)
#     #                 X_imputed.loc[missing, col] = self.models[col].predict(X_missing).flatten()
#     #     return X_imputed



#     def predict(self, X):
#         X_imputed = X.copy()
#         for iteration in range(10):  # Iterative imputation
#             for col in X.columns:
#                 missing = X_imputed[col].isna()
#                 if missing.any():
#                     X_missing = X_imputed[missing].drop(col, axis=1)
#                     predictions = self.models[col].predict(X_missing).flatten()

#                     # Convertir les prédictions au type original
#                     if self.column_types[col].kind in ['i', 'u']:  # Integer types
#                         predictions = np.round(predictions).astype(self.column_types[col])
#                     elif self.column_types[col].kind == 'f':  # Float types
#                         predictions = predictions.astype(self.column_types[col])
#                     elif self.column_types[col] == 'bool':  # Bool types
#                         predictions = (predictions > 0.5).astype(self.column_types[col])  # Conversion en booléen

#                     # Assurer que toutes les valeurs sont positives pour les types numériques
#                     if self.column_types[col].kind in ['i', 'u', 'f']:
#                         predictions = np.maximum(predictions, 0)

#                     X_imputed.loc[missing, col] = predictions

#         return X_imputed

# %%
class CustomImputerModel:
    def __init__(self):
        self.models = {}
        self.column_types = {}  # Pour stocker les types de chaque colonne
        self.min_values = {}    # Pour stocker les valeurs minimales
        self.max_values = {}    # Pour stocker les valeurs maximales

    def fit(self, X_ref, X_train):
        # Utiliser X_ref pour récupérer les types de colonnes, min et max
        for col in X_ref.columns:
            self.column_types[col] = X_ref[col].dtype
            self.min_values[col] = X_ref[col].min()
            self.max_values[col] = X_ref[col].max()

        # Utiliser X_train pour l'entraînement
        for col in X_train.columns:
            features = X_train.drop(col, axis=1)
            target = X_train[col]

            non_missing = target.notna()
            features_non_missing = features[non_missing]
            target_non_missing = target[non_missing]

            # Créer un modèle de réseau de neurones simple
            model = Sequential([
                Input(shape=(features_non_missing.shape[1],)),
                Dense(128, activation='relu'),
                Dense(128, activation='relu'),
                Dense(64, activation='relu'),
                Dense(1)
            ])
            model.compile(optimizer='adam', loss='mean_squared_error',metrics=[R2Score(), MeanAbsolutePercentageError(), MeanAbsoluteError()])

            # Entraîner le modèle
            model.fit(features_non_missing, target_non_missing, epochs=50, batch_size=32, verbose=0)
            self.models[col] = model
            history = model.fit(features_non_missing, target_non_missing, epochs=50, batch_size=32, verbose=0)
        return history
    
    def predict(self, X):
        X_imputed = X.copy()

        for col in X.columns:
            missing = X_imputed[col].isna()
            if missing.any():
                X_missing = X_imputed[missing].drop(col, axis=1)
                predictions = self.models[col].predict(X_missing).flatten()

                # Convertir les prédictions au type original
                if self.column_types[col].kind in ['i', 'u']:
                    predictions = np.round(predictions).astype(self.column_types[col])
                elif self.column_types[col].kind == 'f':
                    predictions = predictions.astype(self.column_types[col])
                
                # Limiter les prédictions aux plages de valeurs minimales et maximales
                predictions = np.clip(predictions, self.min_values[col], self.max_values[col])

                # Assurer que toutes les valeurs sont positives pour les types numériques
                if self.column_types[col].kind in ['i', 'u', 'f']:
                    predictions = np.maximum(predictions, 0)

                X_imputed.loc[missing, col] = predictions

        return X_imputed

# %%
# Initialize and fit the custom model
model = CustomImputerModel()
model.fit(numeric_data, X_train_scaled)

# %%
history = model.fit(numeric_data, X_train_scaled)
# Out:
# ---------------------------------------------
# NameError   Traceback (most recent call last)
# Cell In[53], line 2
#       1 history = model.fit(numeric_data, X_train_scaled)
# ----> 2 size_histories['config']= history
#       3 history.history
#
# NameError: name 'size_histories' is not defined

# %%
size_histories = {}  # Dictionnaire pour stocker les historiques

size_histories['config']= history
history.history
# Out:
# {'loss': [9.357049566460773e-05,
#   6.405203748727217e-05,
#   4.716576586361043e-05,
#   0.0005175347905606031,
#   0.0015854501398280263,
#   0.005678171291947365,
#   0.0005339502822607756,
#   0.0005588627536781132,
#   0.000655567622743547,
#   0.00010782328899949789,
#   0.00554127199575305,
#   0.0008365072426386178,
#   0.0001841253397287801,
#   0.00016253811190836132,
#   0.0010943004162982106,
#   0.008005338720977306,
#   7.757024286547676e-05,
#   3.073757397942245e-05,
#   4.288826312404126e-05,
#   0.00014393850869964808,
#   0.00048541664727963507,
#   0.00590231828391552,
#   0.0013852011179551482,
#   0.0006017609848640859,
#   0.000926221429836005,
#   0.0026409004349261522,
#   0.0005772782606072724,
#   0.0007003581849858165,
#   6.0733382269972935e-05,
#   0.00015649522538296878,
#   0.012970039620995522,
#   0.0018465012544766068,
#   0.00013090888387523592,
#   0.00023171977954916656,
#   6.548795499838889e-05,
#   1.1190463737875689e-05,
#   0.0061156898736953735,
#   0.0009466823539696634,
#   0.0005954427178949118,
#   0.00017221635789610445,
#   6.004003080306575e-05,
#   0.00013517450133804232,
#   3.45176704286132e-05,
#   0.0001650415943004191,
#   0.008221802301704884,
#   0.0031771534122526646,
#   5.796155164716765e-05,
#   0.00047668590559624135,
#   0.0001563214318593964,
#   0.0005384967662394047],
#  'r2_score': [0.9999064207077026,
#   0.9999359250068665,
#   0.9999528527259827,
#   0.9994824528694153,
#   0.9984145760536194,
#   0.9943218231201172,
#   0.999466061592102,
#   0.9994411468505859,
#   0.9993444085121155,
#   0.9998921751976013,
#   0.9944587349891663,
#   0.9991635084152222,
#   0.9998158812522888,
#   0.9998374581336975,
#   0.9989057183265686,
#   0.9919946789741516,
#   0.9999224543571472,
#   0.9999692440032959,
#   0.9999570846557617,
#   0.9998560547828674,
#   0.9995145797729492,
#   0.9940977096557617,
#   0.9986147880554199,
#   0.9993982315063477,
#   0.9990738034248352,
#   0.9973590970039368,
#   0.9994227290153503,
#   0.9992996454238892,
#   0.9999392628669739,
#   0.9998434782028198,
#   0.9870299696922302,
#   0.9981535077095032,
#   0.9998691082000732,
#   0.9997682571411133,
#   0.9999344944953918,
#   0.9999887943267822,
#   0.9938843250274658,
#   0.9990532994270325,
#   0.9994045495986938,
#   0.9998278021812439,
#   0.9999399781227112,
#   0.9998648166656494,
#   0.999965488910675,
#   0.9998349547386169,
#   0.9917781949043274,
#   0.9968228340148926,
#   0.9999420642852783,
#   0.9995233416557312,
#   0.9998436570167542,
#   0.9994615316390991],
#  'mean_absolute_percentage_error': [1.6165603399276733,
#   2.100111961364746,
#   1.4551892280578613,
#   1.9663496017456055,
#   2.383446455001831,
#   3.7050843238830566,
#   1.6288340091705322,
#   1.6922060251235962,
#   1.888792634010315,
#   1.5630687475204468,
#   2.496121883392334,
#   2.2229766845703125,
#   1.7141951322555542,
#   1.6571972370147705,
#   2.048417568206787,
#   2.46925687789917,
#   2.208872079849243,
#   1.9645507335662842,
#   2.5577709674835205,
#   2.4859325885772705,
#   2.3465421199798584,
#   3.104935646057129,
#   1.5814317464828491,
#   1.5522147417068481,
#   1.5501720905303955,
#   2.1023988723754883,
#   2.587913751602173,
#   1.8343032598495483,
#   1.2985361814498901,
#   1.1631503105163574,
#   1.6291652917861938,
#   2.049489974975586,
#   1.5410884618759155,
#   1.2986598014831543,
#   1.027878761291504,
#   0.997001588344574,
#   1.7265371084213257,
#   1.6048599481582642,
#   1.8326150178909302,
#   1.4133386611938477,
#   1.506762981414795,
#   1.5210292339324951,
#   1.7005555629730225,
#   1.3190892934799194,
#   2.5614585876464844,
#   1.4155644178390503,
#   0.8339350819587708,
#   0.834627628326416,
#   0.8528932929039001,
#   1.0428959131240845],
#  'mean_absolute_error': [0.0015526826027780771,
#   0.0018077498534694314,
#   0.0013262460706755519,
#   0.0022278528194874525,
#   0.003345303935930133,
#   0.00619715079665184,
#   0.0022378244902938604,
#   0.0022355858236551285,
#   0.00261632539331913,
#   0.001463884487748146,
#   0.004931201227009296,
#   0.0029329753015190363,
#   0.0017744168872013688,
#   0.0018160432809963822,
#   0.0031780549325048923,
#   0.004965598229318857,
#   0.0019036325393244624,
#   0.0015697893686592579,
#   0.0019446228398010135,
#   0.0021335002966225147,
#   0.002356399782001972,
#   0.005039227660745382,
#   0.002954470459371805,
#   0.0022405022755265236,
#   0.0024636387825012207,
#   0.003863165620714426,
#   0.0028765627648681402,
#   0.0024619970936328173,
#   0.0012183415237814188,
#   0.0013675153022632003,
#   0.005042290315032005,
#   0.003629230661317706,
#   0.0015984472120180726,
#   0.0016468216199427843,
#   0.0010866275988519192,
#   0.0008296501473523676,
#   0.0038828169927001,
#   0.0026201431173831224,
#   0.002371625741943717,
#   0.0015703003155067563,
#   0.001382436603307724,
#   0.0014976392267271876,
#   0.0013677406823262572,
#   0.0013899903278797865,
#   0.005258827470242977,
#   0.0031228256411850452,
#   0.0008993808878585696,
#   0.0015656680334359407,
#   0.001220463658683002,
#   0.0016595878405496478]}

# %%
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['mean_absolute_error'], label='Mean Absolute Error')
plt.title('Courbe d\'apprentissage')
plt.ylabel('Valeur')
plt.xlabel('Époque')
plt.legend()
plt.show()

# %%
plotter.plot(size_histories, metric='accuracy')  # Pour l'accuracy
plt.ylim([0, 1])  # Ajustez selon vos besoins

plotter.plot(size_histories, metric='loss')  # Pour la perte
plt.ylim([0, 1])  # Ajustez selon vos besoins
# Out:
# ---------------------------------------------
# KeyError    Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 plotter.plot(size_histories, metric='accuracy')  # Pour l'accuracy
#       2 plt.ylim([0, 1])  # Ajustez selon vos besoins
#       4 plotter.plot(size_histories, metric='loss')  # Pour la perte
#
# File ~\2024\E1\.venv\lib\site-packages\tensorflow_docs\plots\__init__.py:89, in HistoryPlotter.plot(self, histories, metric, smoothing_std)
#      86   color = COLOR_CYCLE[len(self.color_table) % len(COLOR_CYCLE)]
#      87   self.color_table[name] = color
# ---> 89 train_value = history.history[metric]
#      90 val_value = history.history['val_' + metric]
#      91 if smoothing_std is not None:
#
# KeyError: 'accuracy'

# %%
from joblib import dump

# Supposons que `model` est votre modèle entraîné
dump(imputer_model, 'C:/Users/utilisateur/2024/models/model.joblib')
# Out:
# ['C:/Users/utilisateur/2024/models/model.joblib']

# %%
# Impute missing values in the test set
X_test_imputed = imputer_model.predict(X_test)

# Show the first few rows of the imputed test set
X_test_imputed.head()
# Out:
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 1/8 [==>...........................] - ETA: 0s
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# 8/8 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# 9/9 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# 8/8 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# 8/8 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
# /tmp/ipykernel_58686/3201796851.py:53: RuntimeWarning: invalid value encountered in cast
#   predictions = np.round(predictions).astype(self.column_types[col])
#               ID   Price    Levy  Engine volume  Mileage(km)  Cylinders  \
# 1516  45649679.0  5018.0  1399.0            3.5     167222.0        6.0
# 2420  45815912.0  2979.0   751.0            2.4     191848.0        4.0
# 9726  45766261.0     1.0  1399.0            3.5          0.0        6.0
# 1372  45816654.0   314.0  2410.0            6.2     274771.0        8.0
# 8296  20746880.0    70.0     0.0            1.8      50000.0        6.0
#
#       Airbags  Fuel type_CNG  Fuel type_Diesel  Fuel type_Hybrid  \
# 1516      0.0            0.0               0.0               1.0
# 2420     12.0            0.0               0.0               0.0
# 9726     12.0            0.0               1.0               1.0
# 1372     12.0            0.0               0.0               0.0
# 8296      8.0            0.0               0.0               0.0
#
#       Fuel type_Hydrogen  Fuel type_LPG  Fuel type_Petrol  \
# 1516                 1.0            0.0               0.0
# 2420                 0.0            0.0               1.0
# 9726                 0.0            0.0               0.0
# 1372                 0.0            0.0               1.0
# 8296                 0.0            0.0               0.0
#
#       Fuel type_Plug-in Hybrid
# 1516                       0.0
# 2420                       0.0
# 9726                       0.0
# 1372                       0.0
# 8296                       0.0

# %%
X_test_imputed = scaler.inverse_transform(X_test_imputed)
X_test_imputed = pd.DataFrame(X_test_imputed, columns=X_test.columns)

# %%
 X_test_imputed
# Out:
#               ID    Price    Levy  Engine volume  Mileage(km)  Cylinders  \
# 1516  45649679.0   5018.0  1399.0            3.5     167222.0        6.0
# 2420  45815912.0   2979.0   751.0            2.4     191848.0        4.0
# 9726  45766261.0      1.0  1399.0            3.5          0.0        6.0
# 1372  45816654.0    314.0  2410.0            6.2     274771.0        8.0
# 8296  20746880.0     70.0     0.0            1.8      50000.0        6.0
# ...          ...      ...     ...            ...          ...        ...
# 4115  45506364.0  17876.0   749.0            2.4    2111669.0        4.0
# 9572  45764477.0  29793.0  1053.0            3.5     219030.0        6.0
# 6315  45816654.0  28225.0   707.0            2.0     200000.0        4.0
# 7666  45811158.0    706.0   135.0            2.4     275654.0        4.0
# 565   42971782.0  16935.0   781.0            1.4      15333.0        4.0
#
#       Airbags  Fuel type_CNG  Fuel type_Diesel  Fuel type_Hybrid  \
# 1516      0.0            0.0               0.0               1.0
# 2420     12.0            0.0               0.0               0.0
# 9726     12.0            0.0               1.0               1.0
# 1372     12.0            0.0               0.0               0.0
# 8296      8.0            0.0               0.0               0.0
# ...       ...            ...               ...               ...
# 4115      8.0            0.0               0.0               0.0
# 9572     12.0            0.0               1.0               0.0
# 6315      0.0            0.0               0.0               0.0
# 7666     12.0            0.0               0.0               1.0
# 565       8.0            0.0               0.0               0.0
#
#       Fuel type_Hydrogen  Fuel type_LPG  Fuel type_Petrol  \
# 1516                 1.0            0.0               0.0
# 2420                 0.0            0.0               1.0
# 9726                 0.0            0.0               0.0
# 1372                 0.0            0.0               1.0
# 8296                 0.0            0.0               0.0
# ...                  ...            ...               ...
# 4115                 0.0            0.0               1.0
# 9572                 0.0            0.0               0.0
# 6315                 0.0            0.0               1.0
# 7666                 0.0            0.0               0.0
# 565                  0.0            0.0               0.0
#
#       Fuel type_Plug-in Hybrid
# 1516                       0.0
# 2420                       0.0
# 9726                       0.0
# 1372                       0.0
# 8296                       0.0
# ...                        ...
# 4115                       0.0
# 9572                       0.0
# 6315                       0.0
# 7666                       0.0
# 565                        0.0
#
# [2555 rows x 14 columns]

# %%
# Debugging: Check for NaN values after imputation
nan_count_after = X_test_imputed.isna().sum().sum()
print("NaN count after imputation:", nan_count_after)
# Out:
# NaN count after imputation: 347

# %%
perc=  ((3589-nan_count_after)*100)/3589
perc
# Out:
# 90.33156868208414

# %%
comp = X_test_origine.compare(X_test_imputed)

# %%
comp.head(50)
# Out:
#         ID             Price       Levy        Engine volume        \
#       self       other  self other self  other          self other
# 1516   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 9726   NaN         NaN   NaN   1.0  NaN    NaN           NaN   NaN
# 1372   NaN  45816654.0   NaN   NaN  NaN    NaN           NaN   NaN
# 8296   NaN  20746880.0   NaN   NaN  NaN    0.0           NaN   NaN
# 6560   NaN         NaN   NaN   NaN  NaN    0.0           NaN   NaN
# 5635   NaN  20746880.0   NaN   NaN  NaN    0.0           NaN   NaN
# 3877   NaN         NaN   NaN   NaN  NaN  437.0           NaN   NaN
# 10983  NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 6618   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 9132   NaN  20746880.0   NaN   NaN  NaN    NaN           NaN   0.1
# 9624   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 3613   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 10691  NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 9500   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 9112   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 5220   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 518    NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 8723   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 5007   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 12619  NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 11089  NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 4667   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 1807   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 10282  NaN         NaN   NaN   1.0  NaN    NaN           NaN   0.1
# 9743   NaN         NaN   NaN   NaN  NaN    0.0           NaN   NaN
# 4339   NaN  20746880.0   NaN   NaN  NaN    0.0           NaN   NaN
# 7322   NaN         NaN   NaN   1.0  NaN    NaN           NaN   NaN
# 12553  NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 6503   NaN  20746880.0   NaN   NaN  NaN    NaN           NaN   NaN
# 3499   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 4176   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 6455   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 6428   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 11135  NaN         NaN   NaN   NaN  NaN    NaN           NaN   7.3
# 9265   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 12691  NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 357    NaN         NaN   NaN   1.0  NaN    NaN           NaN   NaN
# 7624   NaN  20746880.0   NaN   NaN  NaN    NaN           NaN   NaN
# 12050  NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 2417   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 3615   NaN  44467596.0   NaN   NaN  NaN    NaN           NaN   NaN
# 8558   NaN         NaN   NaN   1.0  NaN    NaN           NaN   NaN
# 2392   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 6594   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 839    NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 3694   NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 1945   NaN  20746880.0   NaN   NaN  NaN    NaN           NaN   NaN
# 11744  NaN         NaN   NaN   NaN  NaN    0.0           NaN   NaN
# 811    NaN         NaN   NaN   NaN  NaN    NaN           NaN   NaN
# 8046   NaN  20746880.0   NaN   NaN  NaN    NaN           NaN   NaN
#
#       Mileage(km)             ... Fuel type_Hybrid       Fuel type_Hydrogen  \
#              self      other  ...             self other               self
# 1516          NaN        NaN  ...              NaN   NaN                NaN
# 9726          NaN        0.0  ...              NaN   1.0                NaN
# 1372          NaN        NaN  ...              NaN   NaN                NaN
# 8296          NaN        NaN  ...              NaN   NaN                NaN
# 6560          NaN        NaN  ...              NaN   NaN                NaN
# 5635          NaN        NaN  ...              NaN   NaN                NaN
# 3877          NaN        NaN  ...              NaN   NaN                NaN
# 10983         NaN        NaN  ...              NaN   NaN                NaN
# 6618          NaN        NaN  ...              NaN   NaN                NaN
# 9132          NaN        NaN  ...              NaN   NaN                NaN
# 9624          NaN        NaN  ...              NaN   NaN                NaN
# 3613          NaN        NaN  ...              NaN   0.0                NaN
# 10691         NaN        NaN  ...              NaN   NaN                NaN
# 9500          NaN        NaN  ...              NaN   NaN                NaN
# 9112          NaN        NaN  ...              NaN   NaN                NaN
# 5220          NaN        NaN  ...              NaN   NaN                NaN
# 518           NaN        NaN  ...              NaN   NaN                NaN
# 8723          NaN        NaN  ...              NaN   NaN                NaN
# 5007          NaN        0.0  ...              NaN   NaN                NaN
# 12619         NaN        NaN  ...              NaN   NaN                NaN
# 11089         NaN        NaN  ...              NaN   NaN                NaN
# 4667          NaN        0.0  ...              NaN   NaN                NaN
# 1807          NaN        NaN  ...              NaN   NaN                NaN
# 10282         NaN        NaN  ...              NaN   NaN                NaN
# 9743          NaN  2113426.0  ...              NaN   NaN                NaN
# 4339          NaN        NaN  ...              NaN   NaN                NaN
# 7322          NaN        NaN  ...              NaN   NaN                NaN
# 12553         NaN        NaN  ...              NaN   NaN                NaN
# 6503          NaN        NaN  ...              NaN   NaN                NaN
# 3499          NaN        NaN  ...              NaN   NaN                NaN
# 4176          NaN        NaN  ...              NaN   NaN                NaN
# 6455          NaN        NaN  ...              NaN   NaN                NaN
# 6428          NaN        NaN  ...              NaN   NaN                NaN
# 11135         NaN        NaN  ...              NaN   NaN                NaN
# 9265          NaN        NaN  ...              NaN   NaN                NaN
# 12691         NaN        NaN  ...              NaN   NaN                NaN
# 357           NaN        NaN  ...              NaN   NaN                NaN
# 7624          NaN        NaN  ...              NaN   NaN                NaN
# 12050         NaN        NaN  ...              NaN   NaN                NaN
# 2417          NaN        NaN  ...              NaN   NaN                NaN
# 3615          NaN        NaN  ...              NaN   NaN                NaN
# 8558          NaN  2057169.0  ...              NaN   NaN                NaN
# 2392          NaN        NaN  ...              NaN   NaN                NaN
# 6594          NaN        NaN  ...              NaN   NaN                NaN
# 839           NaN        NaN  ...              NaN   NaN                NaN
# 3694          NaN        NaN  ...              NaN   1.0                NaN
# 1945          NaN        NaN  ...              NaN   NaN                NaN
# 11744         NaN        NaN  ...              NaN   NaN                NaN
# 811           NaN        NaN  ...              NaN   NaN                NaN
# 8046          NaN        NaN  ...              NaN   NaN                NaN
#
#             Fuel type_LPG       Fuel type_Petrol        \
#       other          self other             self other
# 1516    1.0           NaN   NaN              NaN   NaN
# 9726    NaN           NaN   NaN              NaN   NaN
# 1372    NaN           NaN   NaN              NaN   NaN
# 8296    NaN           NaN   NaN              NaN   0.0
# 6560    NaN           NaN   NaN              NaN   NaN
# 5635    NaN           NaN   0.0              NaN   NaN
# 3877    NaN           NaN   NaN              NaN   NaN
# 10983   NaN           NaN   NaN              NaN   NaN
# 6618    1.0           NaN   NaN              NaN   NaN
# 9132    NaN           NaN   NaN              NaN   NaN
# 9624    NaN           NaN   NaN              NaN   NaN
# 3613    NaN           NaN   NaN              NaN   0.0
# 10691   NaN           NaN   NaN              NaN   0.0
# 9500    NaN           NaN   NaN              NaN   NaN
# 9112    NaN           NaN   NaN              NaN   NaN
# 5220    NaN           NaN   NaN              NaN   NaN
# 518     0.0           NaN   0.0              NaN   NaN
# 8723    NaN           NaN   NaN              NaN   NaN
# 5007    NaN           NaN   NaN              NaN   NaN
# 12619   0.0           NaN   NaN              NaN   0.0
# 11089   NaN           NaN   0.0              NaN   NaN
# 4667    NaN           NaN   NaN              NaN   NaN
# 1807    0.0           NaN   NaN              NaN   NaN
# 10282   NaN           NaN   NaN              NaN   NaN
# 9743    NaN           NaN   NaN              NaN   NaN
# 4339    NaN           NaN   NaN              NaN   NaN
# 7322    1.0           NaN   NaN              NaN   NaN
# 12553   1.0           NaN   NaN              NaN   NaN
# 6503    1.0           NaN   NaN              NaN   NaN
# 3499    NaN           NaN   NaN              NaN   NaN
# 4176    0.0           NaN   0.0              NaN   NaN
# 6455    1.0           NaN   NaN              NaN   NaN
# 6428    NaN           NaN   0.0              NaN   NaN
# 11135   NaN           NaN   NaN              NaN   NaN
# 9265    NaN           NaN   NaN              NaN   0.0
# 12691   NaN           NaN   0.0              NaN   NaN
# 357     NaN           NaN   0.0              NaN   NaN
# 7624    NaN           NaN   NaN              NaN   0.0
# 12050   1.0           NaN   NaN              NaN   NaN
# 2417    NaN           NaN   NaN              NaN   NaN
# 3615    NaN           NaN   NaN              NaN   NaN
# 8558    NaN           NaN   NaN              NaN   NaN
# 2392    NaN           NaN   NaN              NaN   NaN
# 6594    NaN           NaN   NaN              NaN   NaN
# 839     1.0           NaN   NaN              NaN   NaN
# 3694    NaN           NaN   NaN              NaN   NaN
# 1945    1.0           NaN   NaN              NaN   NaN
# 11744   NaN           NaN   NaN              NaN   NaN
# 811     1.0           NaN   NaN              NaN   NaN
# 8046    NaN           NaN   NaN              NaN   NaN
#
#       Fuel type_Plug-in Hybrid
#                           self other
# 1516                       NaN   NaN
# 9726                       NaN   NaN
# 1372                       NaN   NaN
# 8296                       NaN   NaN
# 6560                       NaN   0.0
# 5635                       NaN   NaN
# 3877                       NaN   NaN
# 10983                      NaN   NaN
# 6618                       NaN   NaN
# 9132                       NaN   NaN
# 9624                       NaN   NaN
# 3613                       NaN   NaN
# 10691                      NaN   NaN
# 9500                       NaN   0.0
# 9112                       NaN   NaN
# 5220                       NaN   NaN
# 518                        NaN   NaN
# 8723                       NaN   NaN
# 5007                       NaN   NaN
# 12619                      NaN   0.0
# 11089                      NaN   NaN
# 4667                       NaN   NaN
# 1807                       NaN   0.0
# 10282                      NaN   NaN
# 9743                       NaN   NaN
# 4339                       NaN   NaN
# 7322                       NaN   NaN
# 12553                      NaN   NaN
# 6503                       NaN   NaN
# 3499                       NaN   NaN
# 4176                       NaN   NaN
# 6455                       NaN   NaN
# 6428                       NaN   NaN
# 11135                      NaN   NaN
# 9265                       NaN   NaN
# 12691                      NaN   NaN
# 357                        NaN   NaN
# 7624                       NaN   NaN
# 12050                      NaN   NaN
# 2417                       NaN   NaN
# 3615                       NaN   NaN
# 8558                       NaN   NaN
# 2392                       NaN   NaN
# 6594                       NaN   NaN
# 839                        NaN   NaN
# 3694                       NaN   NaN
# 1945                       NaN   NaN
# 11744                      NaN   NaN
# 811                        NaN   NaN
# 8046                       NaN   NaN
#
# [50 rows x 28 columns]
